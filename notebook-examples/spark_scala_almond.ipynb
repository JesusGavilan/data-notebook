// %%
import $ivy.`org.apache.spark::spark-sql:3.2.0`
// Out:
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/spark/spark-sql_2.12/3.2.0/spark-sql_2.12-3.2.0.pom
// Downloaded https://repo1.maven.org/maven2/sh/almond/almond-spark_2.12/0.13.7/almond-spark_2.12-0.13.7.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/spark/spark-parent_2.12/3.2.0/spark-parent_2.12-3.2.0.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/apache/18/apache-18.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/orc/orc-mapreduce/1.6.11/orc-mapreduce-1.6.11.pom
// Downloaded https://repo1.maven.org/maven2/org/apache/parquet/parquet-hadoop/1.12.1/parquet-hadoop-1.12.1.pom
// Downloaded https://repo1.maven.org/maven2/org/apache/orc/orc-core/1.6.11/orc-core-1.6.11.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/xbean/xbean-asm9-shaded/4.20/xbean-asm9-shaded-4.20.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/apache/spark/spark-tags_2.12/3.2.0/spark-tags_2.12-3.2.0.pom
// ...

// %%
import $ivy.`io.delta::delta-core:2.0.1`
// Out:
// ...
// Downloaded https://repo1.maven.org/maven2/io/delta/delta-core_2.12/2.0.1/delta-core_2.12-2.0.1.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/codehaus/jackson/jackson-core-asl/1.9.13/jackson-core-asl-1.9.13.pom
// Downloaded https://repo1.maven.org/maven2/io/delta/delta-storage/2.0.1/delta-storage-2.0.1.pom
// ...
// Downloaded https://repo1.maven.org/maven2/org/codehaus/jackson/jackson-core-asl/1.9.13/jackson-core-asl-1.9.13.jar
// Downloaded https://repo1.maven.org/maven2/io/delta/delta-storage/2.0.1/delta-storage-2.0.1-sources.jar
// Downloaded https://repo1.maven.org/maven2/io/delta/delta-storage/2.0.1/delta-storage-2.0.1.jar
// Downloaded https://repo1.maven.org/maven2/org/codehaus/jackson/jackson-core-asl/1.9.13/jackson-core-asl-1.9.13-sources.jar
// Downloaded https://repo1.maven.org/maven2/io/delta/delta-core_2.12/2.0.1/delta-core_2.12-2.0.1-sources.jar
// Downloaded https://repo1.maven.org/maven2/io/delta/delta-core_2.12/2.0.1/delta-core_2.12-2.0.1.jar
// import $ivy.$

// %%
import $ivy.`sh.almond::almond-spark:0.13.7`
// Out:
// import $ivy.$

// %%
import io.delta._
import io.delta.tables._
import org.apache.spark.sql.functions._
// Out:
// import io.delta._
//
// import io.delta.tables._
//
// import org.apache.spark.sql.functions._

// %%
// Import required libraries
import org.apache.spark.sql.functions._
import org.apache.spark.sql.SparkSession
import io.delta._

// Start Spark session
val spark = SparkSession.builder()
  .appName("Delta Example")
  .master("local[*]")
  .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
  .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
  .getOrCreate()

// Set up a sample data frame
val df = spark.range(0, 5)
// Save data frame as Delta Lake table
df.write.format("delta").mode("overwrite").save("delta-example")
// Read data from Delta Lake table
val deltaDF = spark.read.format("delta").load("delta-example")

// Display Delta Lake table data
deltaDF.show()
// Out:
// SLF4J: No SLF4J providers were found.
// SLF4J: Defaulting to no-operation (NOP) logger implementation
// SLF4J: See https://www.slf4j.org/codes.html#noProviders for further details.
// Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
// +---+
// | id|
// +---+
// |  4|
// |  1|
// |  2|
// |  0|
// |  3|
// +---+
// import org.apache.spark.sql.functions._
//
// import org.apache.spark.sql.SparkSession
//
// import io.delta._
//
// // Start Spark session
//
// spark: SparkSession = org.apache.spark.sql.SparkSession@6445b717
// df: org.apache.spark.sql.Dataset[java.lang.Long] = [id: bigint]
// deltaDF: org.apache.spark.sql.package.DataFrame = [id: bigint]

// %%
deltaDF.printSchema()
// Out:
// root
//  |-- id: long (nullable = true)

// %%
import scala.util
util.Properties.versionNumberString
// Out:
// import scala.util
//
// res7_1: String = "2.12.15"
